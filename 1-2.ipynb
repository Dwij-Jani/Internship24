# %%
#Define and import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#reading csv database file
data = pd.read_csv('Mall_Customers.csv')

# %%
#printing table
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#fetching info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
#Fetching columns
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
plt.scatter(data['Age'],data['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
plt.scatter(data['Age'],data['Annual Income (k$)'])
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.show()

# %%
plt.scatter(data["Spending Score (1-100)"], data["Annual Income (k$)"])
plt.xlabel("Spending Score (1-100)")
plt.ylabel("Annual Income (k$)")
# Out:
# Text(0, 0.5, 'Annual Income (k$)')

# %%
#Choosing Relevant cols
rel_col = ["Age","Annual Income (k$)","Spending Score (1-100)"]
customer_df = data[rel_col]
customer_df
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
#importing scaler libs
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(customer_df)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(customer_df)

# %%
scaled_data
# Out:
# array([[-1.42456879, -1.73899919, -0.43480148],
#        [-1.28103541, -1.73899919,  1.19570407],
#        [-1.3528021 , -1.70082976, -1.71591298],
#        [-1.13750203, -1.70082976,  1.04041783],
#        [-0.56336851, -1.66266033, -0.39597992],
#        [-1.20926872, -1.66266033,  1.00159627],
#        [-0.27630176, -1.62449091, -1.71591298],
#        [-1.13750203, -1.62449091,  1.70038436],
#        [ 1.80493225, -1.58632148, -1.83237767],
#        [-0.6351352 , -1.58632148,  0.84631002],
#        [ 2.02023231, -1.58632148, -1.4053405 ],
#        [-0.27630176, -1.58632148,  1.89449216],
#        [ 1.37433211, -1.54815205, -1.36651894],
#        [-1.06573534, -1.54815205,  1.04041783],
#        [-0.13276838, -1.54815205, -1.44416206],
#        [-1.20926872, -1.54815205,  1.11806095],
#        [-0.27630176, -1.50998262, -0.59008772],
#        [-1.3528021 , -1.50998262,  0.61338066],
#        [ 0.94373197, -1.43364376, -0.82301709],
#        [-0.27630176, -1.43364376,  1.8556706 ],
# ...

# %%
#determining the best number of cluster
def find_best_cluster(data,maximum_K):
    clusters_centers = []
    k_values = []
    for k in range(2,maximum_K):
        kmeans_model = KMeans(n_clusters = k)
        kmeans_model.fit(data)
        clusters_centers.append(kmeans_model.inertia_)
        k_values.append(k)
    return clusters_centers, k_values

# %%
clusters_centers, k_values = find_best_cluster(scaled_data, 12)

# %%
#Generating plotting
def generate_elbow_plot(clusters_centers, k_values):
    
    figure = plt.subplots(figsize = (12, 6))
    plt.plot(k_values, clusters_centers, 'o-', color = 'blue')
    plt.xlabel("Number of Clusters (K)")
    plt.ylabel("Cluster Inertia")
    plt.title("Elbow Plot of KMeans")
    plt.show()

# %%
generate_elbow_plot(clusters_centers, k_values)

# %%
kmeans_model = KMeans(n_clusters = 5)
kmeans_model.fit(scaled_data)
# Out:
# KMeans(n_clusters=5)

# %%
#Accessing the cluster by using label attri
data['clusters'] = kmeans_model.labels_
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      clusters
# 0           3
# 1           3
# 2           3
# 3           3
# ...

# %%
plt.scatter(data['Spending Score (1-100)'], data['Annual Income (k$)'], c = data['clusters'])
