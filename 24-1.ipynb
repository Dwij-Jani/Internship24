# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv("counterfeit_train.csv")
sns.boxplot(x=data['Medicine_MRP'])
data.describe(include='all')
# Out:
# C:\Users\Dwij\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
#        Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  \
# count         6818         5652.000000        6818   6818.000000
# unique        1557                 NaN          10           NaN
# top          RQS74                 NaN     Area017           NaN
# freq             9                 NaN         760           NaN
# mean           NaN           14.115057         NaN   1995.836316
# std            NaN            4.649668         NaN      8.368979
# min            NaN            5.855000         NaN   1983.000000
# 25%            NaN            9.995000         NaN   1985.000000
# 50%            NaN           13.800000         NaN   1997.000000
# ...
